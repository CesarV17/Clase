# %%
import numpy as np
import pandas as pd

df = pd.read_excel('datasets/BaseDeDatosVisualizacion.xlsx',
                  sheet_name = 'Drinking_Water_Quality_Distribu',
                  engine = 'openpyxl')
df.head(2)
# Out:
#    Sample Number Sample Date Sample Time Sample Site Sample class  \
# 0      201500023  2015-01-01    12:19:00        1S07  Operational
# 1      201500024  2015-01-01    11:15:00        1S04  Operational
#
#    Residual Free Chlorine (mg/L) Turbidity (NTU) Fluoride (mg/L)  \
# 0                           0.58            0.96            0.79
# 1                           0.71            0.94             0.8
#
#   Coliform (Quanti-Tray) (MPN /100mL) E.coli(Quanti-Tray) (MPN/100mL)
# 0                                  <1                              <1
# 1                                  <1                              <1

# %%
df.columns
# Out:
# Index(['Sample Number', 'Sample Date', 'Sample Time', 'Sample Site',
#        'Sample class', 'Residual Free Chlorine (mg/L)', 'Turbidity (NTU)',
#        'Fluoride (mg/L)', 'Coliform (Quanti-Tray) (MPN /100mL)',
#        'E.coli(Quanti-Tray) (MPN/100mL)'],
#       dtype='object')

# %%
df.drop('Fluoride (mg/L)',
       axis =1,
       inplace = True)

df.head(2)
# Out:
#    Sample Number Sample Date Sample Time Sample Site Sample class  \
# 0      201500023  2015-01-01    12:19:00        1S07  Operational
# 1      201500024  2015-01-01    11:15:00        1S04  Operational
#
#    Residual Free Chlorine (mg/L) Turbidity (NTU)  \
# 0                           0.58            0.96
# 1                           0.71            0.94
#
#   Coliform (Quanti-Tray) (MPN /100mL) E.coli(Quanti-Tray) (MPN/100mL)
# 0                                  <1                              <1
# 1                                  <1                              <1

# %%
df['Residual Free Chlorine (mg/L)'].describe()
# Out:
# count    40432.000000
# mean         0.584161
# std          0.205532
# min          0.000000
# 25%          0.450000
# 50%          0.590000
# 75%          0.720000
# max          2.200000
# Name: Residual Free Chlorine (mg/L), dtype: float64

# %%
import seaborn as sns

sns.boxplot(df['Residual Free Chlorine (mg/L)'])
