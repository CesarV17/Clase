# %% [raw]
# -Introducción
# -Variables críticas, sus comportamientos y relaciones más importantes que existen entre ellas y otras variables (Un estudio de los variables)
# -Modelos utilizados para predecir las variables críticas
# -Escenarios que consideraste (¿cuáles son algunas de las preguntas que podrías responder?)
# -Stakeholders (empresa, sector de la sociedad, organismo descentralizado, gobierno, etc.) que estaría interesado en las preguntas que identificaste en el punto 4.
# -Estudio profundo de una o dos preguntas posibles utilizando visualizaciones de datos (gráfico circular, diagrama de caja, gráfico de líneas, tabla dinámica, gráfico de barras, etc.) aprendido en esta clase.
# -Conclusiones

# %% [raw]
# César Amador Viera Villarreal
# A01283503
#
# Visualización de datos para la toma de decisiones (Gpo 4)
# Evaluación Final
#
# Se estará utilizando la base de datos "Canada" para analizar los patrones de immigración a Canada a lo largo de los años.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_excel('datasets/Canada.xlsx',
                  sheet_name = 'Canada by Citizenship',
                  skiprows = range(20),
                   skipfooter = 2,
                  engine = 'openpyxl')
df.head(2)
